# %%
from PIL import Image
from matplotlib import image
from matplotlib import pyplot as plt
from numpy import asarray
from sklearn.model_selection import train_test_split
import random
import seaborn as sns
import numpy as np

from keras.preprocessing.image import ImageDataGenerator

from os import listdir
import os

from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %% [markdown]
# ## Image Generation

# %%
image_gen = ImageDataGenerator(rotation_range=30, # rotate the image 30 degrees
                               width_shift_range=0.2, # Shift the pic width by a max of 20%
                               height_shift_range=0.2, # Shift the pic height by a max of 20%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.2, # Shear means cutting away part of the image (max 20%)
                               zoom_range=0.3, # Zoom in by 30% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Defining Image Dimension

# %%
# width,height,channels
image_shape = (256,256,3)

# %% [markdown]
# ## Creating the Model #1

# %%
model = Sequential()

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=(256,256,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=32, kernel_size=(3,3),activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=16, kernel_size=(3,3),activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())

model.add(Dense(256, activation='relu'))

# Dropouts help reduce overfitting by randomly turning neurons off during training.
# Here we say randomly turn off 10% of neurons.
model.add(Dropout(0.1))

# Add a densely-connected layer with 128 neurons.
model.add(Dense(128, activation='relu'))

# Let's try to avoid overfitting!
model.add(Dropout(0.1))

# Add a densely-connected layer with 64 neurons.
model.add(Dense(64, activation='relu'))

# Let's try to avoid overfitting!
model.add(Dropout(0.1))


# Last layer, remember its binary, 0=cat , 1=dog
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 254, 254, 64)      1792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 32)      18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 16)        4624
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 14400)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               3686656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 3,752,753
# Trainable params: 3,752,753
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the Model: Attempt 1

# %%
batch_size = 50

train_image_gen = image_gen.flow_from_directory('./data/simple/processed/train/',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')

epoch_step = len(train_image_gen.filenames)//batch_size
print(epoch_step)
# Out:
# Found 3814 images belonging to 2 classes.
# 76

# %%
test_image_gen = image_gen.flow_from_directory('./data/simple/processed/test/',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')

valid_step = len(test_image_gen.filenames)//batch_size
print(valid_step)
# Out:
# Found 954 images belonging to 2 classes.
# 19

# %%
train_image_gen.class_indices
# Out:
# {'Contemporary': 0, 'Modern': 1}

# %%
test_image_gen.class_indices
# Out:
# {'Contemporary': 0, 'Modern': 1}

# %%
results = model.fit_generator(train_image_gen,epochs=30,
                              steps_per_epoch=epoch_step,
                              validation_data=test_image_gen,
                              validation_steps=valid_step,
                              verbose=1)
# Out:
# Epoch 1/30
# 76/76 [==============================] - 90s 1s/step - loss: 0.6954 - accuracy: 0.5003 - val_loss: 0.6921 - val_accuracy: 0.5042
# Epoch 2/30
# 76/76 [==============================] - 71s 941ms/step - loss: 0.6933 - accuracy: 0.5056 - val_loss: 0.6942 - val_accuracy: 0.5000
# Epoch 3/30
# 76/76 [==============================] - 69s 914ms/step - loss: 0.6933 - accuracy: 0.4976 - val_loss: 0.6936 - val_accuracy: 0.5055
# Epoch 4/30
# 76/76 [==============================] - 67s 881ms/step - loss: 0.6933 - accuracy: 0.5008 - val_loss: 0.6920 - val_accuracy: 0.5133
# Epoch 5/30
# 76/76 [==============================] - 66s 863ms/step - loss: 0.6935 - accuracy: 0.4992 - val_loss: 0.6938 - val_accuracy: 0.5055
# Epoch 6/30
# 76/76 [==============================] - 64s 844ms/step - loss: 0.6933 - accuracy: 0.4912 - val_loss: 0.6918 - val_accuracy: 0.5077
# Epoch 7/30
# 76/76 [==============================] - 65s 851ms/step - loss: 0.6932 - accuracy: 0.4952 - val_loss: 0.6906 - val_accuracy: 0.5100
# Epoch 8/30
# 76/76 [==============================] - 67s 882ms/step - loss: 0.6938 - accuracy: 0.4989 - val_loss: 0.6906 - val_accuracy: 0.4889
# Epoch 9/30
# 76/76 [==============================] - 63s 830ms/step - loss: 0.6948 - accuracy: 0.4851 - val_loss: 0.6936 - val_accuracy: 0.5111
# Epoch 10/30
# 76/76 [==============================] - 61s 809ms/step - loss: 0.6932 - accuracy: 0.4973 - val_loss: 0.6909 - val_accuracy: 0.5155
# Epoch 11/30
# 76/76 [==============================] - 62s 812ms/step - loss: 0.6933 - accuracy: 0.4968 - val_loss: 0.6897 - val_accuracy: 0.5066
# Epoch 12/30
# 76/76 [==============================] - 59s 782ms/step - loss: 0.6932 - accuracy: 0.4963 - val_loss: 0.6932 - val_accuracy: 0.4923
# Epoch 13/30
# 76/76 [==============================] - 59s 778ms/step - loss: 0.6931 - accuracy: 0.5077 - val_loss: 0.6922 - val_accuracy: 0.5055
# Epoch 14/30
# 76/76 [==============================] - 59s 779ms/step - loss: 0.6933 - accuracy: 0.4984 - val_loss: 0.6922 - val_accuracy: 0.5044
# Epoch 15/30
# 76/76 [==============================] - 60s 789ms/step - loss: 0.6931 - accuracy: 0.4997 - val_loss: 0.6931 - val_accuracy: 0.5033
# Epoch 16/30
# 76/76 [==============================] - 60s 789ms/step - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6903 - val_accuracy: 0.5022
# Epoch 17/30
# 76/76 [==============================] - 60s 792ms/step - loss: 0.6933 - accuracy: 0.4904 - val_loss: 0.6927 - val_accuracy: 0.5011
# Epoch 18/30
# 76/76 [==============================] - 60s 795ms/step - loss: 0.6931 - accuracy: 0.5016 - val_loss: 0.6996 - val_accuracy: 0.5033
# Epoch 19/30
# 76/76 [==============================] - 60s 790ms/step - loss: 0.6931 - accuracy: 0.5072 - val_loss: 0.6927 - val_accuracy: 0.5011
# Epoch 20/30
# 76/76 [==============================] - 60s 792ms/step - loss: 0.6933 - accuracy: 0.4955 - val_loss: 0.7135 - val_accuracy: 0.5055
# Epoch 21/30
# 76/76 [==============================] - 60s 787ms/step - loss: 0.6933 - accuracy: 0.5030 - val_loss: 0.6943 - val_accuracy: 0.5021
# Epoch 22/30
# 76/76 [==============================] - 68s 890ms/step - loss: 0.6928 - accuracy: 0.5130 - val_loss: 0.6953 - val_accuracy: 0.5033
# Epoch 23/30
# 76/76 [==============================] - 65s 853ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6914 - val_accuracy: 0.5033
# Epoch 24/30
# 76/76 [==============================] - 64s 842ms/step - loss: 0.6931 - accuracy: 0.5005 - val_loss: 0.6890 - val_accuracy: 0.5343
# Epoch 25/30
# 76/76 [==============================] - 63s 834ms/step - loss: 0.6933 - accuracy: 0.5038 - val_loss: 0.6928 - val_accuracy: 0.4801
# Epoch 26/30
# 76/76 [==============================] - 63s 823ms/step - loss: 0.6934 - accuracy: 0.4973 - val_loss: 0.6874 - val_accuracy: 0.5321
# Epoch 27/30
# 76/76 [==============================] - 63s 823ms/step - loss: 0.6913 - accuracy: 0.5271 - val_loss: 0.7149 - val_accuracy: 0.4690
# Epoch 28/30
# 76/76 [==============================] - 62s 819ms/step - loss: 0.6929 - accuracy: 0.5093 - val_loss: 0.6925 - val_accuracy: 0.5122
# Epoch 29/30
# 76/76 [==============================] - 61s 797ms/step - loss: 0.6913 - accuracy: 0.5225 - val_loss: 0.7066 - val_accuracy: 0.5066
# Epoch 30/30
# 76/76 [==============================] - 59s 772ms/step - loss: 0.6916 - accuracy: 0.5236 - val_loss: 0.6963 - val_accuracy: 0.5265

# %%
plt.plot(results.history['accuracy'])

# %%
# Check out our train loss and test loss over epochs.
train_loss = results.history['loss']
test_loss = results.history['val_loss']

# Set figure size.
plt.figure(figsize=(12, 8))

# Generate line plot of training, testing loss over epochs.
plt.plot(train_loss, label='Training Loss', color='#185fad')
plt.plot(test_loss, label='Testing Loss', color='orange')

# Set title
plt.title('Training and Testing Loss by Epoch', fontsize = 25)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Categorical Crossentropy', fontsize = 18)

plt.legend(fontsize = 18);

# %%
test_proba = model.predict_generator(test_image_gen)

# %%
plt.figure(figsize=(12,8))
sns.distplot(test_proba)
plt.title('Prediction Probability Dsitribution')
plt.xlabel('Predicted Probability')
plt.ylabel('Frequency');
